# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import app, reviews, Sort, reviews
import pandas as pd
import csv

# %%
scrapreview = reviews(
    'id.co.bankbkemobile.digitalbank',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=20000
)

# %%
with open('ulasan_aplikasi.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])
    for review in scrapreview[0]:
        writer.writerow([review['content']])

# %%
app_reviews_df = pd.DataFrame(scrapreview[0])
app_reviews_df.shape
app_reviews_df.head()
app_reviews_df.to_csv('ulasan_aplikasi.csv', index=False)
app_reviews_df = pd.DataFrame(scrapreview[0])
jumlah_ulasan, jumlah_kolom = app_reviews_df.shape
app_reviews_df.head()
# Out:
#                                reviewId         userName  \
# 0  31418d00-cebe-4996-a279-9a5cfb2e9e61  Pengguna Google
# 1  868e54f7-05fb-4f9a-896c-0a8ab6cd95cd  Pengguna Google
# 2  0f632e94-c28f-46c9-aa54-15597e4b3f91  Pengguna Google
# 3  77e863c8-9ac0-42de-8be2-489024a30451  Pengguna Google
# 4  017e2f67-8d00-4739-9373-b195bbdc2f86  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Asli berguna juga programnya dan internalnya l...      5              2
# 1  Asli simpel juga, programnya dan interlnya leb...      5              1
# 2  Asli oke juga, program & internalnya lebih fle...      5              1
# 3  Asli berguna banget! programnya dan internalny...      5              1
# 4  Asli praktis sekali! Programnya dan internalny...      5              0
#
#   reviewCreatedVersion                  at  \
# 0               3.28.0 2025-10-14 15:31:39
# 1               3.28.0 2025-10-14 16:03:40
# 2               3.28.0 2025-10-15 16:54:22
# 3               3.28.0 2025-10-15 17:37:00
# 4               3.28.0 2025-10-15 22:39:31
#
#                                         replyContent           repliedAt  \
# 0  Hi Sobat SeaBank, mohon maaf atas ketidaknyama... 2025-10-14 18:28:28
# 1  Hi Sobat SeaBank, mohon maaf atas ketidaknyama... 2025-10-14 18:29:51
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT
#
#   appVersion
# 0     3.28.0
# 1     3.28.0
# 2     3.28.0
# 3     3.28.0
# 4     3.28.0
